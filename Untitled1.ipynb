# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img =cv2.imread('img012.jpg')

# %%
img.shape
# Out:
# (300, 480, 3)

# %%
x,y=img.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b0722e07c69f> in <module>()
# ----> 1 x,y=img.shape
#
# ValueError: too many values to unpack (expected 2)

# %%
img_cx,img_cy=img[:,:,0].shape

# %%
cX=0,cY=0
# Out:
#   File "<ipython-input-18-bfa55c2e7424>", line 1
#     cX=0,cY=0
#       ^
# SyntaxError: can't assign to literal

# %%
cx=0

# %%
cy=0

# %%
type(cx)
# Out:
# int

# %%
type(img_cx)
# Out:
# int

# %%
cX=0 
cY=0
dist = math.hypot(img_cx/2 - cX, img_cy/2 - cY)

# %%
dist
# Out:
# 283.0194339616981

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img =cv2.imread('img012.jpg')
cv2.imshow("img",img)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (300, 480, 3)
